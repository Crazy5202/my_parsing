# %%
from datetime import datetime, timedelta

# %%
date_str = "2025/09/04"
cur_date = datetime.strptime(date_str, "%Y/%m/%d").date()

def calc_date(date: datetime):
    date = date - timedelta(days=1)
    return date, date.strftime("%Y/%m/%d")

# %%
import requests
import time
from bs4 import BeautifulSoup
from random import uniform
import os
import re

# %%
base_url = "https://ixbt.games/news/"

DATA_FOLDER = 'parsed_game_news'

connect_timeout = 100
read_timeout = 100

# %%
parsed_dir = os.path.join(os.getcwd(), DATA_FOLDER)
os.makedirs(parsed_dir, exist_ok=True)

# %%
def get_soup(url: str):
    response = requests.get(url, verify=False, timeout=(connect_timeout, read_timeout))
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup

# %%
# cur_date, date_str = calc_date(cur_date)

# url = base_url + date_str

# response = requests.get(url, verify=False, timeout=(connect_timeout, read_timeout))
# soup = BeautifulSoup(response.content, 'html.parser')

# link_data = soup.find('div', class_=re.compile('news grid'))
# links = link_data.find_all('a', href=True)
# all_links = [link['href'] for link in links]

# soup = get_soup(all_links[0])

# %%
# all_links

# %%
# title_data = soup.find('div', class_=re.compile('news flex'))
# title_data.find('h1')
# text_data = soup.find('article', class_=re.compile('prose-stone'))
# title_data.find_all('p')

# %%
# text_data = soup.find('article', class_=re.compile('prose-stone'))
# text_data.find_all('p')

# %%
from pymongo import AsyncMongoClient
import json
import asyncio

# %%
MONGO_URI = "mongodb://admin:password123@localhost:27017/"
DB_NAME = "html_storage"
COLLECTION_NAME = "html_documents"

# %%
async def connect_to_mongodb():
    """Connect to MongoDB and return client and database objects"""
    try:
        client = AsyncMongoClient(MONGO_URI)

        await client.admin.command("ping")
        print("Connected successfully")
        
        db = client[DB_NAME]
        return client, db
    except Exception as e:
        raise Exception("Unable to connect: ", e)

async def upload_html_document(db, html_content, url, metadata=None):
    """Upload HTML content to MongoDB"""
    
    if metadata is None:
        metadata = {}
    
    document = {
        "url": url,
        "html_content": html_content,
        "metadata": metadata,
        "upload_date": datetime.now(),
        "content_type": "text/html",
        "size_bytes": len(html_content.encode('utf-8'))
    }
    
    collection = db[COLLECTION_NAME]
    result = await collection.insert_one(document)
    
    print(f"HTML document uploaded successfully! Document ID: {result.inserted_id}")

# %%
client, db = await connect_to_mongodb()
# Out:
# Connected successfully

# %%
counter = 1
while True:
    # Выбираем день
    cur_date, date_str = calc_date(cur_date)

    # Берём ссылки на новости
    url = base_url + date_str

    date_str = date_str.replace("/", "-")

    hub_soup = get_soup(url)

    link_data = hub_soup.find('div', class_=re.compile('news grid'))
    links = link_data.find_all('a', href=True)
    all_links = [link['href'] for link in links]

    # Проходимся по ссылкам на новости
    for link in all_links:
        file_name = str(date_str) + "_" + str(counter)

        file_path = os.path.join(parsed_dir, file_name + ".html")

        article_soup = get_soup(link)

        # Берём данные по заголовку
        title_data = article_soup.find('div', class_=re.compile('news flex'))
        title = title_data.find('h1')

        # Берём данные по тексту
        text_data = article_soup.find('article', class_=re.compile('prose-stone'))
        text_list = text_data.find_all('p') 

        print(f"Webpage {file_name} parsed")

        # Пишем в файл
        f = open(file_path, 'w', encoding="utf-8")

        f.write(str(title))
        for elem in text_list:
            f.write(str(elem))

        f.close()

        print(f"Webpage {file_name} written")

        # Читаем файл и загружаем в MongoDB

        f = open(file_path, 'r', encoding="utf-8")

        file_data = f.read()
        
        await upload_html_document(db=db, html_content=file_data, url = link)        

        print(f"Webpage {file_name} uploaded")

        counter += 1

        wait_time = uniform(0, 3)
        time.sleep(wait_time)

    print(f"Date {date_str} cleared")

    counter = 1
# Out:
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_1 parsed
# Webpage 2025-08-28_1 written
# HTML document uploaded successfully! Document ID: 68d3192b006260f32d5a6801
# Webpage 2025-08-28_1 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_2 parsed
# Webpage 2025-08-28_2 written
# HTML document uploaded successfully! Document ID: 68d3192d006260f32d5a6802
# Webpage 2025-08-28_2 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_3 parsed
# Webpage 2025-08-28_3 written
# HTML document uploaded successfully! Document ID: 68d3192f006260f32d5a6803
# Webpage 2025-08-28_3 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_4 parsed
# Webpage 2025-08-28_4 written
# HTML document uploaded successfully! Document ID: 68d31931006260f32d5a6804
# Webpage 2025-08-28_4 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_5 parsed
# Webpage 2025-08-28_5 written
# HTML document uploaded successfully! Document ID: 68d31932006260f32d5a6805
# Webpage 2025-08-28_5 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_6 parsed
# Webpage 2025-08-28_6 written
# HTML document uploaded successfully! Document ID: 68d31934006260f32d5a6806
# Webpage 2025-08-28_6 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_7 parsed
# Webpage 2025-08-28_7 written
# HTML document uploaded successfully! Document ID: 68d3193b006260f32d5a6807
# Webpage 2025-08-28_7 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_8 parsed
# Webpage 2025-08-28_8 written
# HTML document uploaded successfully! Document ID: 68d3193d006260f32d5a6808
# Webpage 2025-08-28_8 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_9 parsed
# Webpage 2025-08-28_9 written
# HTML document uploaded successfully! Document ID: 68d3193f006260f32d5a6809
# Webpage 2025-08-28_9 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_10 parsed
# Webpage 2025-08-28_10 written
# HTML document uploaded successfully! Document ID: 68d31940006260f32d5a680a
# Webpage 2025-08-28_10 uploaded
# /home/Maxim/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2025-08-28_11 parsed
# Webpage 2025-08-28_11 written
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[26], line 52
#      48 f = open(file_path, 'r', encoding="utf-8")
#      50 file_data = f.read()
# ---> 52 await upload_html_document(db=db, html_content=file_data, url = link)
#      54 print(f"Webpage {file_name} uploaded")
#      56 counter += 1
#
# Cell In[19], line 30, in upload_html_document(db, html_content, url, metadata)
#      20 document = {
#      21     "url": url,
#      22     "html_content": html_content,
#    (...)
#      26     "size_bytes": len(html_content.encode('utf-8'))
#      27 }
#      29 collection = db[COLLECTION_NAME]
# ---> 30 result = await collection.insert_one(document)
#      32 print(f"HTML document uploaded successfully! Document ID: {result.inserted_id}")
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/collection.py:892, in AsyncCollection.insert_one(self, document, bypass_document_validation, session, comment)
#     888     document["_id"] = ObjectId()  # type: ignore[index]
#     890 write_concern = self._write_concern_for(session)
#     891 return InsertOneResult(
# --> 892     await self._insert_one(
#     893         document,
#     894         ordered=True,
#     895         write_concern=write_concern,
#     896         op_id=None,
#     897         bypass_doc_val=bypass_document_validation,
#     898         session=session,
#     899         comment=comment,
#     900     ),
#     901     write_concern.acknowledged,
#     902 )
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/collection.py:832, in AsyncCollection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     820     result = await conn.command(
#     821         self._database.name,
#     822         command,
#    (...)
#     827         retryable_write=retryable_write,
#     828     )
#     830     _check_write_command_response(result)
# --> 832 await self._database.client._retryable_write(
#     833     acknowledged, _insert_command, session, operation=_Op.INSERT
#     834 )
#     836 if not isinstance(doc, RawBSONDocument):
#     837     return doc.get("_id")
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/mongo_client.py:2086, in AsyncMongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2072 """Execute an operation with consecutive retries if possible
#    2073
#    2074 Returns func()'s return value on success. On error retries the same
#    (...)
#    2083 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2084 """
#    2085 async with self._tmp_session(session) as s:
# -> 2086     return await self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/mongo_client.py:1972, in AsyncMongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1967 # Ensure that the options supports retry_writes and there is a valid session not in
#    1968 # transaction, otherwise, we will not support retry behavior for this txn.
#    1969 retryable = bool(
#    1970     retryable and self.options.retry_writes and session and not session.in_transaction
#    1971 )
# -> 1972 return await self._retry_internal(
#    1973     func=func,
#    1974     session=session,
#    1975     bulk=bulk,
#    1976     operation=operation,
#    1977     retryable=retryable,
#    1978     operation_id=operation_id,
#    1979 )
#
# File ~/.local/lib/python3.10/site-packages/pymongo/_csot.py:115, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     113         with _TimeoutContext(timeout):
#     114             return await func(self, *args, **kwargs)
# --> 115 return await func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/mongo_client.py:2007, in AsyncMongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1981 @_csot.apply
#    1982 async def _retry_internal(
#    1983     self,
#    (...)
#    1992     operation_id: Optional[int] = None,
#    1993 ) -> T:
#    1994     """Internal retryable helper for all client transactions.
#    1995
#    1996     :param func: Callback function we want to retry
#    (...)
#    2005     :return: Output of the calling func()
#    2006     """
# -> 2007     return await _ClientConnectionRetryable(
#    2008         mongo_client=self,
#    2009         func=func,
#    2010         bulk=bulk,
#    2011         operation=operation,
#    2012         is_read=is_read,
#    2013         session=session,
#    2014         read_pref=read_pref,
#    2015         address=address,
#    2016         retryable=retryable,
#    2017         operation_id=operation_id,
#    2018     ).run()
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/mongo_client.py:2775, in _ClientConnectionRetryable.run(self)
#    2773 self._check_last_error(check_csot=True)
#    2774 try:
# -> 2775     return await self._read() if self._is_read else await self._write()
#    2776 except ServerSelectionTimeoutError:
#    2777     # The application may think the write was never attempted
#    2778     # if we raise ServerSelectionTimeoutError on the retry
#    2779     # attempt. Raise the original exception instead.
#    2780     self._check_last_error()
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/mongo_client.py:2907, in _ClientConnectionRetryable._write(self)
#    2899         if self._retrying:
#    2900             _debug_log(
#    2901                 _COMMAND_LOGGER,
#    2902                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)
#    2905                 operationId=self._operation_id,
#    2906             )
# -> 2907         return await self._func(self._session, conn, self._retryable)  # type: ignore
#    2908 except PyMongoError as exc:
#    2909     if not self._retryable:
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/collection.py:820, in AsyncCollection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     817 if bypass_doc_val is not None:
#     818     command["bypassDocumentValidation"] = bypass_doc_val
# --> 820 result = await conn.command(
#     821     self._database.name,
#     822     command,
#     823     write_concern=write_concern,
#     824     codec_options=self._write_response_codec_options,
#     825     session=session,
#     826     client=self._database.client,
#     827     retryable_write=retryable_write,
#     828 )
#     830 _check_write_command_response(result)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.message import _BulkWriteContext
#      46 try:
# ---> 47     return await func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/pool.py:441, in AsyncConnection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     439 # Catch socket.error, KeyboardInterrupt, CancelledError, etc. and close ourselves.
#     440 except BaseException as error:
# --> 441     await self._raise_connection_failure(error)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/pool.py:413, in AsyncConnection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return await command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,  # type: ignore[arg-type]
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File ~/.local/lib/python3.10/site-packages/pymongo/asynchronous/network.py:198, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     196     response_doc: _DocumentOut = {"ok": 1}
#     197 else:
# --> 198     reply = await async_receive_message(conn, request_id)
#     199     conn.more_to_come = reply.more_to_come
#     200     unpacked_docs = reply.unpack_response(
#     201         codec_options=codec_options, user_fields=user_fields
#     202     )
#
# File ~/.local/lib/python3.10/site-packages/pymongo/network_layer.py:720, in async_receive_message(conn, request_id, max_message_size)
#     718 tasks = [read_task, cancellation_task]
#     719 try:
# --> 720     done, pending = await asyncio.wait(
#     721         tasks, timeout=timeout, return_when=asyncio.FIRST_COMPLETED
#     722     )
#     723     for task in pending:
#     724         task.cancel()
#
# File /usr/lib64/python3.10/asyncio/tasks.py:384, in wait(fs, timeout, return_when)
#     377     warnings.warn("The explicit passing of coroutine objects to "
#     378                   "asyncio.wait() is deprecated since Python 3.8, and "
#     379                   "scheduled for removal in Python 3.11.",
#     380                   DeprecationWarning, stacklevel=2)
#     382 fs = {ensure_future(f, loop=loop) for f in fs}
# --> 384 return await _wait(fs, timeout, return_when, loop)
#
# File /usr/lib64/python3.10/asyncio/tasks.py:491, in _wait(fs, timeout, return_when, loop)
#     488     f.add_done_callback(_on_completion)
#     490 try:
# --> 491     await waiter
#     492 finally:
#     493     if timeout_handle is not None:
#
# CancelledError:
