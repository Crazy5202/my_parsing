# %%
from datetime import datetime, timedelta

# %%
date_str = "2025/09/15"
cur_date = datetime.strptime(date_str, "%Y/%m/%d").date()

def calc_date(date: datetime):
    date = date - timedelta(days=1)
    return date, date.strftime("%Y/%m/%d")

# %%
for i in range (5):
    
    print(date_str)
# Out:
# 2025/09/14
# 2025/09/13
# 2025/09/12
# 2025/09/11
# 2025/09/10

# %%
import requests
import time
from bs4 import BeautifulSoup
from random import uniform
import os

# %%
base_url = "https://ixbt.games/news/"

DATA_FOLDER = 'parsed_books'

connect_timeout = 100
read_timeout = 100

# %%
parsed_dir = os.path.join(os.getcwd(), DATA_FOLDER)
os.makedirs(parsed_dir, exist_ok=True)

# %%
counter = 1
while True:
    cur_date, date_str = calc_date(cur_date)

    url = base_url + date_str

    file_path = os.path.join(parsed_dir, str(counter) + ".txt")

    f = open(file_path, 'w', encoding="utf-8")

    response = requests.get(url, verify=False, timeout=(connect_timeout, read_timeout))
    soup = BeautifulSoup(response.content, 'html.parser')

    text = soup.get_text()
    f.write(text)
    print(f"Webpage {counter} parsed")
    counter += 1
    wait_time = uniform(0, 3)
    time.sleep(wait_time)
    f.close()
# Out:
# c:\Users\Maxim\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 1 parsed
# c:\Users\Maxim\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 2 parsed
# c:\Users\Maxim\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ixbt.games'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Webpage 3 parsed
# ...
